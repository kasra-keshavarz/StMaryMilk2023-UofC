# %%
import pandas as pd
import os

# %%
# Replace 'your_file.txt' with the actual file path
file_path = '/home/paulc600/scratch/PRMS/02_directory/inputs/precip_m.day'

# %%
# output path
output_folder_path = '/home/paulc600/scratch/PRMS/02_directory/inputs/'

# %%
# read precipitation in m
precipitation = pd.read_csv(file_path, sep='\t', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_145112/2231170847.py in <module>
#       1 # read precipitation in m
# ----> 2 precipitation = pd.read_csv(file_path, sep='\t', index_col=0)
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
precipitation
# Out:
#                58219     58241     58237     58232     58214     58233  \
# time
# 1980-01-01  0.000754  0.000938  0.000873  0.000344  0.000113  0.000604
# 1980-01-02  0.000651  0.000967  0.000936  0.000403  0.000193  0.001030
# 1980-01-03  0.004440  0.005170  0.004770  0.001050  0.000325  0.003270
# 1980-01-04  0.000467  0.000369  0.000340  0.000198  0.000141  0.000175
# 1980-01-05  0.017000  0.017600  0.017400  0.014800  0.012300  0.017000
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-27  0.000664  0.000655  0.000654  0.000476  0.000400  0.000745
# 2018-12-28  0.000418  0.000420  0.000401  0.000253  0.000141  0.000312
# 2018-12-29  0.013200  0.017800  0.017000  0.008170  0.002620  0.014900
# 2018-12-30  0.006500  0.006870  0.006540  0.004100  0.004040  0.004910
# 2018-12-31  0.000290  0.000227  0.000248  0.000527  0.000514  0.000340
#
#                58213     58223     58221     58216  ...     58448     58380  \
# ...

# %%
# Multiply all values in the DataFrame by 1000 (m to mm)
p_mm= precipitation.multiply(1000)

# %%
p_mm

# %% [markdown]
# Check if timezone converted precipitation has the same sum as not converted

# %%
precipitation_old = pd.read_csv('/home/paulc600/scratch/HYPE/MODIS/08_inputs/Tobs.txt', sep='\t', index_col=0)

# %%
precipitation_old
# Out:
#             58219  58241  58237  58232  58214  58233  58213  58223  58221  \
# time
# 1980-01-01  -2.97  -3.42  -3.38  -2.91  -1.85  -3.13  -1.61  -2.94  -1.23
# 1980-01-02  -3.88  -3.79  -3.87  -5.74  -6.07  -3.85  -6.65  -5.60  -6.42
# 1980-01-03  -5.12  -5.57  -5.56  -5.50  -4.07  -5.54  -3.86  -5.38  -3.85
# 1980-01-04  -9.05  -8.82  -8.89  -9.62 -10.90  -8.91 -11.40  -9.84  -9.79
# 1980-01-05 -12.40 -12.60 -12.70 -13.50 -13.00 -13.10 -13.20 -13.30 -13.40
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2018-12-27  -9.97 -10.40 -10.40 -10.70  -9.54 -10.50  -9.54 -10.50  -9.78
# 2018-12-28 -12.10 -12.10 -12.30 -16.00 -14.10 -12.70 -14.60 -15.20 -15.10
# 2018-12-29  -8.77  -9.53  -9.49  -8.72  -7.29  -9.40  -7.08  -8.69  -6.64
# 2018-12-30  -4.80  -5.34  -5.34  -5.42  -4.02  -5.42  -3.92  -5.26  -4.01
# 2018-12-31 -15.50 -16.00 -16.10 -16.40 -15.20 -16.40 -15.10 -16.20 -15.10
#
# ...

# %%
sum_rows_columns_df1 = p_mm.sum().sum()

# %%
sum_rows_columns_df1
# Out:
# 30725838.849447444

# %%
sum_rows_columns_df2 = precipitation_old.sum().sum()

# %%
sum_rows_columns_df2
# Out:
# 30748332.065846916

# %%
p_mm.to_csv(os.path.join(output_folder_path, 'Pobs.txt'), sep='\t', na_rep='', index_label='time')
